# %%
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import GRU
# Out:
# Using TensorFlow backend.

# %%
def get_finger_tip(frame, side):
    if side in frame['hands']:
        finger_name = ['thumb', 'index', 'middle', 'ring', 'pinky']

        finger_tip = np.zeros([3, 5]) # [cooridinate x finger]
        finger_tipd = {}
        for idx, finger in enumerate(finger_name):
            finger_tipd['d'] = frame['hands'][side]['fingers'][finger]['bones']['distal']['next_joint']
            finger_tip[:, idx] = np.array(frame['hands'][side]['fingers'][finger]['bones']['distal']['next_joint'])
        print(finger_tipd)

        return finger_tip

# %%
import json
import pandas as pd
import numpy as np
features = pd.DataFrame(columns=[
    'left_thumb', 'left_index', 'left_middle', 'left_ring', 'left_pinky',
    'right_thumb', 'right_index', 'right_middle', 'right_ring', 'right_pinky'
])
feature = {}

# %%
try:
    with open("./record/one/json_0.txt") as json_data:
        json_data = json.load(json_data)
except Exception as s:
    print ('error log:', s)
print(get_finger_tip(json_data[0], 'right'))
# for frame in json_data:
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-a6d516e9510c> in <module>()
#       4 except Exception as s:
#       5     print ('error log:', s)
# ----> 6 print(get_finger_tip(json_data[0], 'right'))
#       7 # for frame in json_data:
#       8
#
# <ipython-input-62-3c3b7752cf24> in get_finger_tip(frame, side)
#       6         finger_tipd = {}
#       7         for idx, finger in enumerate(finger_name):
# ----> 8             finger_tipd[side + finger_name] = frame['hands'][side]['fingers'][finger]['bones']['distal']['next_joint']
#       9             finger_tip[:, idx] = np.array(frame['hands'][side]['fingers'][finger]['bones']['distal']['next_joint'])
#      10         print(finger_tipd)
#
# TypeError: cannot concatenate 'str' and 'list' objects

# %%
# Out:
# {u'fingers': 5,
#  u'frame_id': 771634,
#  u'hand_available': 1,
#  u'hands': {u'right': {u'arm': {u'direction': [-0.6525785326957703,
#      0.2269952893257141,
#      -0.7229207754135132],
#     u'elbow_position': [140.1454620361328,
#      269.9855041503906,
#      270.8656311035156],
#     u'wrist_position': [-14.505956649780273,
#      323.780029296875,
#      99.54413604736328]},
#    u'fingers': {u'index': {u'bones': {u'distal': {u'direction': [0.26768144965171814,
#         -0.5110004544258118,
#         0.8168385624885559],
#        u'next_joint': [-58.37680435180664,
#         347.95465087890625,
#         -54.1842155456543],
#        u'prev_joint': [-54.23286056518555,
#         340.0439147949219,
#         -41.53883743286133]},
#       u'intermediate': {u'direction': [0.2947991192340851,
#         -0.46447792649269104,
#         0.8350770473480225],
#        u'next_joint': [-54.23286056518555,
#         340.0439147949219,
#         -41.53883743286133],
# ...
