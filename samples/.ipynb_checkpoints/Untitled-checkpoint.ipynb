# %%
import sys, thread, time
sys.path.insert(0, "../lib")

# %%
import Leap
from PIL import Image

# %%
def checkImageAllow(controller):
    imagesAllowed = controller.config.get("tracking_images_mode") == 2
    if not imagesAllowed:
        # ask user for permission...
        controller.config.set("tracking_images_mode", 2)
        controller.config.save()

# %%
def saveImage(leap_image):
    barray = bytearray(leap_image.width * leap_image.height)
    for d in range(0, leap_image.width * leap_image.height - 1):
        barray[d] = leap_image.data[d]

    image = Image.frombytes("L", (leap_image.width,  leap_image.height), buffer(barray))
    image.save("test.png")

# %%
class SampleListener(Leap.Listener):
    finger_names = ['Thumb', 'Index', 'Middle', 'Ring', 'Pinky']
    bone_names = ['Metacarpal', 'Proximal', 'Intermediate', 'Distal']

    def on_init(self, controller):
        print "Initialized"

    def on_connect(self, controller):
        print "Connected"

    def on_disconnect(self, controller):
        # Note: not dispatched when running in a debugger.
        print "Disconnected"

    def on_exit(self, controller):
        print "Exited"
        
    def on_images(self, controller):
        print "Image Available"
        images = controller.images
        left_image = images[0]
        right_image = images[1]
        
        saveImage(left_image)

    def on_frame(self, controller):
        checkImageAllow(controller)
        controller.set_policy(Leap.Controller.POLICY_IMAGES)
        # Get the most recent frame and report some basic information
        frame = controller.frame()

#         print "Frame id: %d, timestamp: %d, hands: %d, fingers: %d" % (
#               frame.id, frame.timestamp, len(frame.hands), len(frame.fingers))

        # Get hands
        for hand in frame.hands:

            handType = "Left hand" if hand.is_left else "Right hand"

            print "  %s, id %d, position: %s" % (
                handType, hand.id, hand.palm_position)

            # Get the hand's normal vector and direction
            normal = hand.palm_normal
            direction = hand.direction

            # Calculate the hand's pitch, roll, and yaw angles
            print "  pitch: %f degrees, roll: %f degrees, yaw: %f degrees" % (
                direction.pitch * Leap.RAD_TO_DEG,
                normal.roll * Leap.RAD_TO_DEG,
                direction.yaw * Leap.RAD_TO_DEG)

            # Get arm bone
            arm = hand.arm
            print "  Arm direction: %s, wrist position: %s, elbow position: %s" % (
                arm.direction,
                arm.wrist_position,
                arm.elbow_position)

            # Get fingers
            for finger in hand.fingers:

                print "    %s finger, id: %d, length: %fmm, width: %fmm" % (
                    self.finger_names[finger.type],
                    finger.id,
                    finger.length,
                    finger.width)

                # Get bones
                for b in range(0, 4):
                    bone = finger.bone(b)
                    print "      Bone: %s, start: %s, end: %s, direction: %s" % (
                        self.bone_names[bone.type],
                        bone.prev_joint,
                        bone.next_joint,
                        bone.direction)

        if not frame.hands.is_empty:
            print ""

# %%
listener = SampleListener()
controller = Leap.Controller()

# Have the sample listener receive events from the controller
controller.add_listener(listener)
# Out:
# Initialized
# Connected
# True
# Image Available
# Image Available
# Image Available
#   Right hand, id 85, position: (42.1804, 142.647, 14.7429)
#   pitch: 19.429172 degrees, roll: -14.004572 degrees, yaw: -15.320314 degrees
#   Arm direction: (-0.562042, 0.58072, -0.588959), wrist position: (71.3858, 119.326, 76.3578), elbow position: (215.465, -29.5409, 227.337)
#     Thumb finger, id: 850, length: 46.270054mm, width: 18.948446mm
#       Bone: Metacarpal, start: (35.7489, 122.238, 69.015), end: (35.7489, 122.238, 69.015), direction: (0, 0, 0)
#       Bone: Proximal, start: (35.7489, 122.238, 69.015), end: (-8.60757, 134.585, 57.7801), direction: (0.935915, -0.260518, 0.237053)
#       Bone: Intermediate, start: (-8.60757, 134.585, 57.7801), end: (-36.1112, 141.093, 46.9392), direction: (0.908585, -0.214978, 0.358132)
#       Bone: Distal, start: (-36.1112, 141.093, 46.9392), end: (-53.911, 144.358, 36.7295), direction: (0.85666, -0.157145, 0.491365)
#     Index finger, id: 851, length: 52.210594mm, width: 18.099554mm
#       Bone: Metacarpal, start: (44.7342, 141.753, 62.3101), end: (14.3849, 155.692, 0.961594), direction: (0.434492, -0.199556, 0.87829)
#       Bone: Proximal, start: (14.3849, 155.692, 0.961594), end: (-2.6223, 162.791, -32.4336), direction: (0.445882, -0.186129, 0.875526)
#       Bone: Intermediate, start: (-2.6223, 162.791, -32.4336), end: (-12.5492, 154.561, -49.586), direction: (0.4626, 0.383536, 0.799313)
#       Bone: Distal, start: (-12.5492, 154.561, -49.586), end: (-16.5983, 140.837, -54.622), direction: (0.266929, 0.904727, 0.33199)
#     Middle finger, id: 852, length: 59.489784mm, width: 17.776169mm
#       Bone: Metacarpal, start: (54.9946, 142.397, 56.7438), end: (34.4862, 154.581, -5.05227), direction: (0.309604, -0.18394, 0.932905)
#       Bone: Proximal, start: (34.4862, 154.581, -5.05227), end: (23.9776, 165.192, -45.1553), direction: (0.245566, -0.247952, 0.937132)
#       Bone: Intermediate, start: (23.9776, 165.192, -45.1553), end: (14.1064, 158.38, -67.3712), direction: (0.390994, 0.269809, 0.879958)
#       Bone: Distal, start: (14.1064, 158.38, -67.3712), end: (7.39908, 144.663, -74.095), direction: (0.402022, 0.822167, 0.403015)
#     Ring finger, id: 853, length: 57.201015mm, width: 16.915152mm
#       Bone: Metacarpal, start: (65.3953, 140.079, 52.0001), end: (55.5166, 149.57, -5.87357), direction: (0.166105, -0.159583, 0.97311)
#       Bone: Proximal, start: (55.5166, 149.57, -5.87357), end: (54.7809, 158.898, -44.4218), direction: (0.0185465, -0.235152, 0.971782)
#       Bone: Intermediate, start: (54.7809, 158.898, -44.4218), end: (49.3879, 152.935, -67.665), direction: (0.219274, 0.242445, 0.945061)
#       Bone: Distal, start: (49.3879, 152.935, -67.665), end: (42.9411, 140.312, -76.2832), direction: (0.388641, 0.76094, 0.519546)
#     Pinky finger, id: 854, length: 44.844536mm, width: 15.025359mm
#       Bone: Metacarpal, start: (74.8977, 131.074, 48.6531), end: (73.7345, 140.553, -5.56556), direction: (0.021129, -0.172188, 0.984838)
#       Bone: Proximal, start: (73.7345, 140.553, -5.56556), end: (81.8728, 144.694, -35.6009), direction: (-0.25924, -0.131904, 0.956763)
#       Bone: Intermediate, start: (81.8728, 144.694, -35.6009), end: (80.7776, 138.965, -51.9569), direction: (0.0630664, 0.329894, 0.941909)
#       Bone: Distal, start: (80.7776, 138.965, -51.9569), end: (74.3067, 127.603, -59.9071), direction: (0.422847, 0.7425, 0.519513)
#
# Image Available
#   Right hand, id 85, position: (34.7867, 143.517, 61.4397)
#   pitch: 24.524486 degrees, roll: -8.149174 degrees, yaw: -16.026178 degrees
#   Arm direction: (-0.615545, 0.510343, -0.600545), wrist position: (64.24, 117.053, 121.395), elbow position: (221.252, -13.1241, 274.581)
#     Thumb finger, id: 850, length: 46.904171mm, width: 18.745838mm
#       Bone: Metacarpal, start: (28.7861, 116.507, 112.471), end: (28.7861, 116.507, 112.471), direction: (0, 0, 0)
#       Bone: Proximal, start: (28.7861, 116.507, 112.471), end: (-14.6085, 122.768, 95.1017), direction: (0.920177, -0.132767, 0.368304)
#       Bone: Intermediate, start: (-14.6085, 122.768, 95.1017), end: (-38.7717, 124.589, 76.2754), direction: (0.787444, -0.0593593, 0.613521)
#       Bone: Distal, start: (-38.7717, 124.589, 76.2754), end: (-49.8325, 123.734, 58.3707), direction: (0.525126, 0.0405985, 0.850056)
#     Index finger, id: 851, length: 52.926125mm, width: 17.906025mm
#       Bone: Metacarpal, start: (35.9562, 137.333, 108.428), end: (6.40974, 155.328, 48.1456), direction: (0.425105, -0.258899, 0.867327)
#       Bone: Proximal, start: (6.40974, 155.328, 48.1456), end: (-7.72694, 168.495, 14.6523), direction: (0.365613, -0.34055, 0.866229)
#       Bone: Intermediate, start: (-7.72694, 168.495, 14.6523), end: (-15.2018, 160.974, -4.34137), direction: (0.343622, 0.345743, 0.873147)
#       Bone: Distal, start: (-15.2018, 160.974, -4.34137), end: (-17.3193, 147.161, -10.7576), direction: (0.137708, 0.898292, 0.417263)
#     Middle finger, id: 852, length: 60.305073mm, width: 17.586096mm
#       Bone: Metacarpal, start: (46.2162, 139.586, 103.43), end: (26.5958, 156.836, 42.9166), direction: (0.297674, -0.261723, 0.918091)
#       Bone: Proximal, start: (26.5958, 156.836, 42.9166), end: (19.3954, 174.339, 3.88292), direction: (0.165986, -0.403469, 0.899812)
#       Bone: Intermediate, start: (19.3954, 174.339, 3.88292), end: (12.0774, 169.625, -20.1836), direction: (0.285941, 0.184202, 0.940376)
#       Bone: Distal, start: (12.0774, 169.625, -20.1836), end: (7.21198, 155.962, -28.8838), direction: (0.287683, 0.807842, 0.514423)
#     Ring finger, id: 853, length: 57.984936mm, width: 16.734285mm
#       Bone: Metacarpal, start: (56.8826, 138.841, 98.9154), end: (47.9286, 153.99, 42.414), direction: (0.151306, -0.255988, 0.954765)
#       Bone: Proximal, start: (47.9286, 153.99, 42.414), end: (48.4359, 169.73, 5.41498), direction: (-0.0126164, -0.391436, 0.920119)
#       Bone: Intermediate, start: (48.4359, 169.73, 5.41498), end: (44.4274, 165.704, -18.8605), direction: (0.160782, 0.161498, 0.973688)
#       Bone: Distal, start: (44.4274, 165.704, -18.8605), end: (39.4599, 153.035, -28.7382), direction: (0.295413, 0.753437, 0.587421)
#     Pinky finger, id: 854, length: 45.459118mm, width: 14.864699mm
#       Bone: Metacarpal, start: (67.2775, 131.272, 94.9869), end: (66.839, 146.807, 42.457), direction: (0.00800463, -0.283594, 0.958911)
#       Bone: Proximal, start: (66.839, 146.807, 42.457), end: (75.5658, 157.531, 13.7947), direction: (-0.27423, -0.336995, 0.900684)
#       Bone: Intermediate, start: (75.5658, 157.531, 13.7947), end: (75.2307, 154.108, -3.46863), direction: (0.0190398, 0.194501, 0.980718)
#       Bone: Distal, start: (75.2307, 154.108, -3.46863), end: (70.0989, 143.4, -13.4514), direction: (0.330806, 0.690257, 0.643516)
#
# Image Available
#   Right hand, id 85, position: (51.5554, 138.43, 58.2284)
#   pitch: 26.323283 degrees, roll: -3.523465 degrees, yaw: -15.134654 degrees
#   Arm direction: (-0.63545, 0.418782, -0.64871), wrist position: (79.9182, 111.598, 118.653), elbow position: (242.008, 4.7752, 284.126)
#     Thumb finger, id: 850, length: 46.904171mm, width: 18.745838mm
#       Bone: Metacarpal, start: (44.8524, 108.488, 107.506), end: (44.8524, 108.488, 107.506), direction: (0, 0, 0)
#       Bone: Proximal, start: (44.8524, 108.488, 107.506), end: (16.1785, 109.792, 70.0881), direction: (0.608025, -0.0276395, 0.793436)
#       Bone: Intermediate, start: (16.1785, 109.792, 70.0881), end: (0.281401, 109.954, 43.8419), direction: (0.518064, -0.00530777, 0.855326)
#       Bone: Distal, start: (0.281401, 109.954, 43.8419), end: (-6.59088, 109.155, 23.9476), direction: (0.326273, 0.0379521, 0.944513)
#     Index finger, id: 851, length: 52.926125mm, width: 17.906025mm
#       Bone: Metacarpal, start: (50.8884, 129.89, 104.856), end: (23.1549, 149.19, 44.1178), direction: (0.39902, -0.277684, 0.873885)
#       Bone: Proximal, start: (23.1549, 149.19, 44.1178), end: (13.9557, 122.999, 17.2022), direction: (0.237915, 0.677365, 0.696113)
#       Bone: Intermediate, start: (13.9557, 122.999, 17.2022), end: (19.1136, 102.151, 20.6582), direction: (-0.237108, 0.958404, -0.158877)
#       Bone: Distal, start: (19.1136, 102.151, 20.6582), end: (25.2413, 90.9287, 29.1998), direction: (-0.398501, 0.72982, -0.555482)
#     Middle finger, id: 852, length: 60.305073mm, width: 17.586096mm
#       Bone: Metacarpal, start: (61.212, 133.012, 100.498), end: (43.4315, 152.179, 39.9921), direction: (0.26976, -0.2908, 0.917968)
#       Bone: Proximal, start: (43.4315, 152.179, 39.9921), end: (30.3458, 156.859, -1.10129), direction: (0.301655, -0.107887, 0.947293)
#       Bone: Intermediate, start: (30.3458, 156.859, -1.10129), end: (22.324, 146.354, -23.016), direction: (0.313444, 0.410497, 0.856297)
#       Bone: Distal, start: (22.324, 146.354, -23.016), end: (17.7045, 134.567, -34.2306), direction: (0.273138, 0.696928, 0.663089)
#     Ring finger, id: 853, length: 57.984936mm, width: 16.734285mm
#       Bone: Metacarpal, start: (72.1054, 133.146, 96.4945), end: (64.9004, 150.65, 40.4253), direction: (0.12175, -0.295788, 0.947463)
#       Bone: Proximal, start: (64.9004, 150.65, 40.4253), end: (59.6725, 161.079, 1.94361), direction: (0.130011, -0.259358, 0.95699)
#       Bone: Intermediate, start: (59.6725, 161.079, 1.94361), end: (54.2383, 156.583, -21.9694), direction: (0.217964, 0.180339, 0.95915)
#       Bone: Distal, start: (54.2383, 156.583, -21.9694), end: (49.9956, 148.997, -36.3639), direction: (0.252312, 0.451167, 0.85603)
#     Pinky finger, id: 854, length: 45.459118mm, width: 14.864699mm
#       Bone: Metacarpal, start: (83.1275, 126.43, 92.7278), end: (84.2, 144.624, 41.068), direction: (-0.0195782, -0.332133, 0.943029)
#       Bone: Proximal, start: (84.2, 144.624, 41.068), end: (90.6568, 154.332, 11.4577), direction: (-0.202897, -0.305055, 0.93047)
#       Bone: Intermediate, start: (90.6568, 154.332, 11.4577), end: (92.032, 154.944, -6.08052), direction: (-0.0781251, -0.0347803, 0.996337)
#       Bone: Distal, start: (92.032, 154.944, -6.08052), end: (91.6169, 152.098, -21.3245), direction: (0.0267564, 0.183462, 0.982663)
#
# Image Available
#   Right hand, id 85, position: (50.9604, 117.825, 48.6819)
#   pitch: 31.360913 degrees, roll: -10.511631 degrees, yaw: -16.330342 degrees
#   Arm direction: (-0.554492, 0.623158, -0.551555), wrist position: (78.8939, 84.0755, 104.58), elbow position: (218.71, -73.0546, 243.655)
#     Thumb finger, id: 850, length: 46.150089mm, width: 18.414354mm
#       Bone: Metacarpal, start: (44.345, 85.8476, 95.8676), end: (44.345, 85.8476, 95.8676), direction: (0, 0, 0)
#       Bone: Proximal, start: (44.345, 85.8476, 95.8676), end: (21.2684, 85.3689, 55.3651), direction: (0.495019, 0.0102683, 0.868822)
#       Bone: Intermediate, start: (21.2684, 85.3689, 55.3651), end: (11.6051, 83.8083, 26.8035), direction: (0.320056, 0.0516886, 0.945988)
#       Bone: Distal, start: (11.6051, 83.8083, 26.8035), end: (5.97851, 82.5158, 6.89951), direction: (0.271498, 0.0623649, 0.960416)
#     Index finger, id: 851, length: 52.075226mm, width: 17.589392mm
#       Bone: Metacarpal, start: (52.0505, 106.529, 94.1511), end: (23.246, 131.737, 37.0948), direction: (0.419241, -0.366887, 0.83044)
#       Bone: Proximal, start: (23.246, 131.737, 37.0948), end: (7.49538, 144.766, 5.00897), direction: (0.414011, -0.342483, 0.843386)
#       Bone: Intermediate, start: (7.49538, 144.766, 5.00897), end: (-1.31691, 142.782, -14.3949), direction: (0.411724, 0.0927082, 0.906581)
#       Bone: Distal, start: (-1.31691, 142.782, -14.3949), end: (-6.5622, 135.944, -26.8304), direction: (0.34669, 0.45193, 0.821928)
#     Middle finger, id: 852, length: 59.335541mm, width: 17.275120mm
#       Bone: Metacarpal, start: (62.2433, 108.987, 89.4286), end: (43.2232, 133.193, 32.0041), direction: (0.291917, -0.371517, 0.88134)
#       Bone: Proximal, start: (43.2232, 133.193, 32.0041), end: (30.6859, 145.512, -6.8912), direction: (0.293734, -0.288621, 0.911273)
#       Bone: Intermediate, start: (30.6859, 145.512, -6.8912), end: (21.4105, 141.207, -29.9024), direction: (0.368351, 0.170961, 0.913832)
#       Bone: Distal, start: (21.4105, 141.207, -29.9024), end: (15.3066, 131.872, -42.2518), direction: (0.366801, 0.560992, 0.742122)
#     Ring finger, id: 853, length: 57.052704mm, width: 16.438372mm
#       Bone: Metacarpal, start: (72.748, 108.436, 84.8478), end: (64.2135, 129.817, 31.0692), direction: (0.14589, -0.365498, 0.919308)
#       Bone: Proximal, start: (64.2135, 129.817, 31.0692), end: (57.4062, 136.875, -7.26114), direction: (0.172056, -0.178385, 0.968801)
#       Bone: Intermediate, start: (57.4062, 136.875, -7.26114), end: (49.9471, 128.852, -29.2098), direction: (0.304073, 0.327065, 0.894745)
#       Bone: Distal, start: (49.9471, 128.852, -29.2098), end: (44.1794, 118.071, -40.3559), direction: (0.348602, 0.651638, 0.673679)
#     Pinky finger, id: 854, length: 44.728264mm, width: 14.601847mm
#       Bone: Metacarpal, start: (82.779, 101.127, 80.0917), end: (82.6803, 122.195, 30.2062), direction: (0.00182127, -0.389056, 0.921212)
#       Bone: Proximal, start: (82.6803, 122.195, 30.2062), end: (79.2735, 121.16, -0.901915), direction: (0.108804, 0.0330741, 0.993513)
#       Bone: Intermediate, start: (79.2735, 121.16, -0.901915), end: (72.1458, 110.403, -12.4546), direction: (0.411536, 0.621063, 0.667023)
#       Bone: Distal, start: (72.1458, 110.403, -12.4546), end: (64.6587, 97.8727, -16.9167), direction: (0.490522, 0.820929, 0.292343)
#
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
# Image Available
#   Right hand, id 86, position: (-48.6725, 120.09, -2.88949)
#   pitch: -63.628779 degrees, roll: 32.174095 degrees, yaw: -77.502636 degrees
#   Arm direction: (0.376884, -0.8494, 0.369429), wrist position: (1.6139, 165.724, 1.20353), elbow position: (-93.2428, 379.506, -91.7767)
#     Thumb finger, id: 860, length: 46.431988mm, width: 18.941725mm
#       Bone: Metacarpal, start: (3.62578, 125.673, 19.7908), end: (3.62578, 125.673, 19.7908), direction: (0, 0, 0)
#       Bone: Proximal, start: (3.62578, 125.673, 19.7908), end: (-25.5132, 91.1957, 8.50043), direction: (0.626217, 0.740931, 0.242637)
#       Bone: Intermediate, start: (-25.5132, 91.1957, 8.50043), end: (-43.7786, 72.0987, -6.48043), direction: (0.601293, 0.628674, 0.493168)
#       Bone: Distal, start: (-43.7786, 72.0987, -6.48043), end: (-54.2204, 63.5057, -22.3516), direction: (0.500783, 0.412111, 0.761171)
#     Index finger, id: 861, length: 52.393318mm, width: 18.093136mm
#       Bone: Metacarpal, start: (-13.9492, 138.842, 22.226), end: (-68.2943, 98.2232, 12.2327), direction: (0.79244, 0.592288, 0.145718)
#       Bone: Proximal, start: (-68.2943, 98.2232, 12.2327), end: (-100.698, 80.737, 1.77704), direction: (0.846569, 0.45684, 0.273162)
#       Bone: Intermediate, start: (-100.698, 80.737, 1.77704), end: (-118.375, 70.2669, -4.67462), direction: (0.820876, 0.48621, 0.299602)
#       Bone: Distal, start: (-118.375, 70.2669, -4.67462), end: (-129.94, 61.9647, -10.0621), direction: (0.759783, 0.545407, 0.353923)
#     Middle finger, id: 862, length: 59.697979mm, width: 17.769865mm
#       Bone: Metacarpal, start: (-17.9934, 145.416, 13.7304), end: (-71.1252, 111.847, -2.99648), direction: (0.816962, 0.516162, 0.257195)
#       Bone: Proximal, start: (-71.1252, 111.847, -2.99648), end: (-60.4464, 75.1899, -22.6518), direction: (-0.248672, 0.85362, 0.457707)
#       Bone: Intermediate, start: (-60.4464, 75.1899, -22.6518), end: (-35.198, 76.5728, -24.2199), direction: (-0.996589, -0.0545842, 0.0618945)
#       Bone: Distal, start: (-35.198, 76.5728, -24.2199), end: (-22.9368, 87.1377, -19.9361), direction: (-0.732347, -0.631031, -0.255866)
#     Ring finger, id: 863, length: 57.401203mm, width: 16.909153mm
#       Bone: Metacarpal, start: (-19.455, 151.137, 3.91802), end: (-67.5883, 126.424, -18.0363), direction: (0.824324, 0.423231, 0.375986)
#       Bone: Proximal, start: (-67.5883, 126.424, -18.0363), end: (-58.4494, 91.9964, -35.806), direction: (-0.229583, 0.864879, 0.446403)
#       Bone: Intermediate, start: (-58.4494, 91.9964, -35.806), end: (-33.9976, 93.358, -32.7426), direction: (-0.990732, -0.0551691, -0.124123)
#       Bone: Distal, start: (-33.9976, 93.358, -32.7426), end: (-22.4875, 103.441, -26.1888), direction: (-0.691458, -0.605704, -0.393711)
#     Pinky finger, id: 864, length: 45.001480mm, width: 15.020031mm
#       Bone: Metacarpal, start: (-15.4598, 153.785, -8.45275), end: (-60.6559, 137.427, -33.1781), direction: (0.836157, 0.302647, 0.457435)
#       Bone: Proximal, start: (-60.6559, 137.427, -33.1781), end: (-58.75, 108.048, -44.3874), direction: (-0.0605016, 0.932594, 0.35582)
#       Bone: Intermediate, start: (-58.75, 108.048, -44.3874), end: (-41.6072, 107.179, -41.384), direction: (-0.983774, 0.0498307, -0.172352)
#       Bone: Distal, start: (-41.6072, 107.179, -41.384), end: (-29.9428, 115.484, -35.8339), direction: (-0.75956, -0.540786, -0.361414)
#
# Image Available
# Disconnected

# %%
controller.remove_listener(listener)
# Out:
# Exited
# True

# %% [markdown]
# ## Camera

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cap = cv2.VideoCapture(0)
print cap.isOpened()
print cap.get(3)


while True:
    ret, img = cap.read()
    
    if ret == True:
        cv2.imshow('video output', img)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# True
# 640.0

# %%
cap = cv2.VideoCapture(0)
cap.release()

# %%
img = cv2.imread('test.png')
cv2.imshow('frame' ,img)
cv2.waitKey()
