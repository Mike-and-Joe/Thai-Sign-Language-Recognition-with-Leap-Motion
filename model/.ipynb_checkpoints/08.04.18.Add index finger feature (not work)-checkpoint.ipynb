# %%
from keras.preprocessing import sequence
from keras.models import Sequential, Model, load_model
from keras.layers import GRU, Dense, Dropout, Input, concatenate
from keras.utils import np_utils
from keras.optimizers import Adam
import json
import pandas as pd
import numpy as np
import pickle

# %%
# variable
words = [
    'come quickly', 'emergency', 'father', 'fever', 'good luck',
    'headache', 'hello', 'help', 'hi', 'hungry',
    'like', 'mother', 'mother_father', 'mother_mother', 'not ok',
    'quickly', 'sorry', 'tomorrow', 'yogurt'
]
data_per_word = 27
data_length = 2 * data_per_word * len(words)
timesteps = 50
dimensions = 34

# %%
def get_feature(frame):
    finger_name = ['thumb', 'index', 'middle', 'ring', 'pinky']
    hand_name = ['left', 'right']
    
    fingertip_pos = np.zeros([2, 5, 3])
    
    hand_palm_pos = np.zeros([2, 3])
    hand_palm_rpy = np.zeros([2, 3])
    hand_palm_unit_vector = np.zeros([2, 3])
    arm_direction = np.zeros([2, 3])
    dist_fingertip_palm = np.zeros([10])
    
    feature = np.zeros([34])
    
    for hand_idx, hand in enumerate(hand_name):
        if not hand in frame['hands']:
            continue
        hand_palm_pos[hand_idx] = np.array(frame['hands'][hand]['hand_palm_position'])
        hand_palm_rpy[hand_idx] = np.array([ frame['hands'][hand]['roll'],
                                                    frame['hands'][hand]['pitch'],
                                                    frame['hands'][hand]['yaw']])
        hand_palm_unit_vector[hand_idx] = np.cross(
            frame['hands'][hand]['fingers']['index']['bones']['proximal']['direction'],
            frame['hands'][hand]['fingers']['middle']['bones']['proximal']['direction']
        )
        arm_direction[hand_idx] = np.array(frame['hands'][hand]['arm']['direction'])
        for finger_idx, finger in enumerate(finger_name):
            fingertip_pos[hand_idx, finger_idx] = (
                np.array(frame['hands'][hand]['fingers'][finger]['bones']['distal']['next_joint'])
            )
            
    fingertip_pos_shift = np.roll(fingertip_pos, 1, axis=1)
    dist_btw_fingertip = np.linalg.norm(fingertip_pos - fingertip_pos_shift, axis=2)
        
    feature[0:6] = hand_palm_pos.reshape(6)
    feature[6:12] = hand_palm_rpy.reshape(6)
    feature[12:22] = dist_btw_fingertip.reshape(10)
    feature[22:28] = hand_palm_unit_vector.reshape(6)
    feature[28:34] = arm_direction.reshape(6)
    
    return feature

# %%
def get_timesteps(json_data, pick_frame_every_no): 
    timesteps = np.zeros([0, dimensions])
    for frame_no, frame in enumerate(json_data):
        if frame_no % pick_frame_every_no != 0 or not frame['hands']:
            continue
        feature = get_feature(frame)
        timesteps = np.vstack((timesteps, feature))
    return timesteps

# %%
def get_augmentation(percent, old_timesteps, old_pick_frame_every_no):
    timesteps = np.zeros([0, dimensions])
    pick_frame_every_no = old_pick_frame_every_no*(100+percent)//100
    timesteps_length = (old_timesteps.shape[0] * old_pick_frame_every_no) // pick_frame_every_no
    
    for new_index in range(1, timesteps_length):
        start_old_index = (new_index * pick_frame_every_no) // old_pick_frame_every_no
        x1 = old_pick_frame_every_no*start_old_index
        x2 = old_pick_frame_every_no*(start_old_index + 1)
        h1, h2 = old_timesteps[start_old_index : start_old_index + 2]
        _x = (new_index * pick_frame_every_no)
        
        feature = ((_x-x1)/(x2-x1))*(h2-h1) + h1
        
        timesteps = np.vstack((timesteps, feature))
        
    return timesteps

# %%
max_frame = 0
for word_no, word in enumerate(words):
    for data_no in range(data_per_word):
        try:
            with open("./record/{}/json_{}.txt".format(word, data_no)) as json_data:
                json_data = json.load(json_data)
        except Exception as s:
            print ('error log:', s)
        
        if max_frame < len(json_data):
            max_frame = len(json_data)

# %%
speedup = 10
pick_frame_every_no = int((max_frame * (speedup < 0 and (100-speedup)/100 or 1)) // 50 + 1)

# %%
x = np.zeros([0, timesteps, dimensions])
y = np.zeros([0])
for word_no, word in enumerate(words):
    for data_no in range(data_per_word):
        try:
            with open("./record/{}/json_{}.txt".format(word, data_no)) as json_data:
                json_data = json.load(json_data)
        except Exception as s:
            print ('error log:', s)
        
        _timesteps = get_timesteps(json_data, pick_frame_every_no)
        __timesteps = np.vstack((_timesteps, np.zeros([timesteps - _timesteps.shape[0], dimensions])))
        x = np.vstack((x, [__timesteps]))
        y = np.append(y, word_no)
        
        _timesteps = get_augmentation(+10, _timesteps, pick_frame_every_no)
        __timesteps = np.vstack((_timesteps, np.zeros([timesteps - _timesteps.shape[0], dimensions])))
        x = np.vstack((x, [__timesteps]))
        y = np.append(y, word_no)

# %%
x_std = x.std(axis=(0,1), keepdims=True)
x_mean = x.mean(axis=(0,1), keepdims=True)
x_norm = (x-x_mean)/x_std
# x_norm = (x-x_min)/(x_max-x_min)
# x_norm = 2*(x-(x_max+x_min)/2)/(x_max-x_min)

# %%
x_train = np.zeros([data_length * 2 // 3, timesteps, dimensions])
y_train = np.zeros([data_length * 2 // 3])
x_test = np.zeros([data_length // 3, timesteps, dimensions])
y_test = np.zeros([data_length // 3])
for idx in range(data_length):
    if idx % 3 == 2:
        x_test[idx // 3] = x_norm[idx]
        y_test[idx // 3] = y[idx]
    else:
        x_train[idx - idx // 3] = x_norm[idx]
        y_train[idx - idx // 3] = y[idx]

# %%
shuffle_train = np.arange(len(x_train))
np.random.shuffle(shuffle_train)
x_train_shuffle = np.zeros([data_length * 2 // 3, timesteps, dimensions])
y_train_shuffle = np.zeros([data_length * 2 // 3])
for idx, item in enumerate(shuffle_train):
    x_train_shuffle[idx] = x_train[item]
    y_train_shuffle[idx] = y_train[item]

# %%
# encoding label
Y_train_shuffle = np_utils.to_categorical(y_train_shuffle, len(words))
Y_test = np_utils.to_categorical(y_test, len(words))

# %%
fingers = Input(shape=(timesteps, dimensions), name='fingers')
fingers_layers = GRU(64, activation='tanh', recurrent_activation='hard_sigmoid', dropout=0.2, recurrent_dropout=0.2)(fingers)
fingers_layers = Dense(64, activation='relu')(fingers_layers)
fingers_layers = Dropout(0.2)(fingers_layers)
fingers_layers = Dense(64, activation='relu')(fingers_layers)
fingers_layers = Dropout(0.2)(fingers_layers)
fingers_layers = Dense(64, activation='relu')(fingers_layers)
fingers_layers = Dropout(0.2)(fingers_layers)
output_layer = Dense(len(words), activation='softmax')(fingers_layers)
model = Model(inputs=fingers, outputs=output_layer)
adam = Adam(lr=0.01, decay=0.0005)
model.compile(optimizer=adam,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(x_train_shuffle, Y_train_shuffle,validation_data=(x_test, Y_test), epochs=1000, batch_size=8, shuffle=True)
# Out:
# Train on 684 samples, validate on 342 samples
# Epoch 1/1000
# 684/684 [==============================] - 3s 4ms/step - loss: 2.9811 - acc: 0.0351 - val_loss: 2.9472 - val_acc: 0.0526
# Epoch 2/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.9559 - acc: 0.0468 - val_loss: 2.8699 - val_acc: 0.0936
# Epoch 3/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.9228 - acc: 0.0702 - val_loss: 2.8698 - val_acc: 0.0819
# Epoch 4/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.8575 - acc: 0.0833 - val_loss: 2.7951 - val_acc: 0.0936
# Epoch 5/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.8295 - acc: 0.0789 - val_loss: 2.7472 - val_acc: 0.0965
# Epoch 6/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.8106 - acc: 0.0833 - val_loss: 2.7380 - val_acc: 0.0906
# Epoch 7/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.7834 - acc: 0.0716 - val_loss: 2.7482 - val_acc: 0.0731
# Epoch 8/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.7666 - acc: 0.0702 - val_loss: 2.7759 - val_acc: 0.0965
# Epoch 9/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.7372 - acc: 0.0950 - val_loss: 2.7324 - val_acc: 0.1053
# Epoch 10/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.8000 - acc: 0.0877 - val_loss: 2.6849 - val_acc: 0.1228
# Epoch 11/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.7257 - acc: 0.0965 - val_loss: 2.6565 - val_acc: 0.1023
# Epoch 12/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.7453 - acc: 0.0731 - val_loss: 2.6531 - val_acc: 0.1053
# Epoch 13/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.7191 - acc: 0.0731 - val_loss: 2.6446 - val_acc: 0.0936
# Epoch 14/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.6728 - acc: 0.0965 - val_loss: 2.6247 - val_acc: 0.1111
# Epoch 15/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.6508 - acc: 0.0804 - val_loss: 2.5873 - val_acc: 0.1287
# Epoch 16/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.6838 - acc: 0.0994 - val_loss: 2.6814 - val_acc: 0.0994
# Epoch 17/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.6599 - acc: 0.1067 - val_loss: 2.5565 - val_acc: 0.1433
# Epoch 18/1000
# 684/684 [==============================] - 3s 4ms/step - loss: 2.6817 - acc: 0.0994 - val_loss: 2.5763 - val_acc: 0.1287
# Epoch 19/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.6460 - acc: 0.1096 - val_loss: 2.4834 - val_acc: 0.1813
# Epoch 20/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.5933 - acc: 0.1228 - val_loss: 2.5406 - val_acc: 0.1667
# Epoch 21/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.5905 - acc: 0.1170 - val_loss: 2.3768 - val_acc: 0.1901
# Epoch 22/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.5123 - acc: 0.1272 - val_loss: 2.3471 - val_acc: 0.1784
# Epoch 23/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.5194 - acc: 0.1272 - val_loss: 2.3883 - val_acc: 0.1696
# Epoch 24/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 2.4890 - acc: 0.1404 - val_loss: 2.3478 - val_acc: 0.1667
# Epoch 25/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 2.4523 - acc: 0.1374 - val_loss: 2.2755 - val_acc: 0.1754
# Epoch 26/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.4922 - acc: 0.1418 - val_loss: 2.3043 - val_acc: 0.1608
# Epoch 27/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.4790 - acc: 0.1257 - val_loss: 2.3304 - val_acc: 0.1667
# Epoch 28/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.4438 - acc: 0.1520 - val_loss: 2.2242 - val_acc: 0.1813
# Epoch 29/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 2.4338 - acc: 0.1228 - val_loss: 2.2623 - val_acc: 0.1725
# Epoch 30/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 2.3615 - acc: 0.1681 - val_loss: 2.2029 - val_acc: 0.2135
# Epoch 31/1000
# 684/684 [==============================] - 3s 4ms/step - loss: 2.3916 - acc: 0.1667 - val_loss: 2.3007 - val_acc: 0.2018
# Epoch 32/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.4601 - acc: 0.1433 - val_loss: 2.3209 - val_acc: 0.1754
# Epoch 33/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.3893 - acc: 0.1564 - val_loss: 2.2307 - val_acc: 0.1901
# Epoch 34/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.4209 - acc: 0.1433 - val_loss: 2.2290 - val_acc: 0.1754
# Epoch 35/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.3460 - acc: 0.1550 - val_loss: 2.1693 - val_acc: 0.2164
# Epoch 36/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 2.3673 - acc: 0.1696 - val_loss: 2.1837 - val_acc: 0.2368
# Epoch 37/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.3259 - acc: 0.1301 - val_loss: 2.1904 - val_acc: 0.2251
# Epoch 38/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.3267 - acc: 0.1725 - val_loss: 2.1572 - val_acc: 0.2485
# Epoch 39/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.2958 - acc: 0.1769 - val_loss: 2.0906 - val_acc: 0.2368
# Epoch 40/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.3311 - acc: 0.1827 - val_loss: 2.1589 - val_acc: 0.2661
# Epoch 41/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.2614 - acc: 0.1740 - val_loss: 2.0649 - val_acc: 0.2661
# Epoch 42/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.2055 - acc: 0.1988 - val_loss: 2.0358 - val_acc: 0.2836
# Epoch 43/1000
# 684/684 [==============================] - 3s 4ms/step - loss: 2.2238 - acc: 0.2120 - val_loss: 2.0075 - val_acc: 0.2778
# Epoch 44/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 2.2461 - acc: 0.1974 - val_loss: 2.0049 - val_acc: 0.2632
# Epoch 45/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.2452 - acc: 0.2076 - val_loss: 1.9825 - val_acc: 0.2895
# Epoch 46/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.1650 - acc: 0.2149 - val_loss: 1.9822 - val_acc: 0.2982
# Epoch 47/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 2.1751 - acc: 0.2558 - val_loss: 1.9268 - val_acc: 0.2690
# Epoch 48/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 2.1923 - acc: 0.2208 - val_loss: 1.9128 - val_acc: 0.3363
# Epoch 49/1000
# 684/684 [==============================] - 3s 4ms/step - loss: 2.1474 - acc: 0.2398 - val_loss: 1.9094 - val_acc: 0.3012
# Epoch 50/1000
# 684/684 [==============================] - 3s 4ms/step - loss: 2.1598 - acc: 0.2237 - val_loss: 1.9028 - val_acc: 0.3304
# Epoch 51/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.1258 - acc: 0.2295 - val_loss: 1.8960 - val_acc: 0.3216
# Epoch 52/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.1731 - acc: 0.2368 - val_loss: 1.9094 - val_acc: 0.3450
# Epoch 53/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.1173 - acc: 0.2485 - val_loss: 1.8462 - val_acc: 0.3216
# Epoch 54/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.1062 - acc: 0.2427 - val_loss: 1.8179 - val_acc: 0.3509
# Epoch 55/1000
# 684/684 [==============================] - 3s 4ms/step - loss: 2.0679 - acc: 0.2588 - val_loss: 1.8213 - val_acc: 0.3626
# Epoch 56/1000
# 684/684 [==============================] - 3s 4ms/step - loss: 2.1154 - acc: 0.2646 - val_loss: 1.8559 - val_acc: 0.3246
# Epoch 57/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 2.1086 - acc: 0.2602 - val_loss: 1.8202 - val_acc: 0.3304
# Epoch 58/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.0814 - acc: 0.2383 - val_loss: 1.8060 - val_acc: 0.3246
# Epoch 59/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 2.0767 - acc: 0.2558 - val_loss: 1.7890 - val_acc: 0.3567
# Epoch 60/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.0044 - acc: 0.2558 - val_loss: 1.7514 - val_acc: 0.3509
# Epoch 61/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.1069 - acc: 0.2427 - val_loss: 1.7383 - val_acc: 0.3684
# Epoch 62/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.0297 - acc: 0.2895 - val_loss: 1.7105 - val_acc: 0.3596
# Epoch 63/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.9740 - acc: 0.2763 - val_loss: 1.6912 - val_acc: 0.3509
# Epoch 64/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.0201 - acc: 0.2573 - val_loss: 1.7297 - val_acc: 0.3889
# Epoch 65/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 2.0010 - acc: 0.2822 - val_loss: 1.7112 - val_acc: 0.3801
# Epoch 66/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.9820 - acc: 0.2617 - val_loss: 1.7144 - val_acc: 0.3772
# Epoch 67/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.9804 - acc: 0.2865 - val_loss: 1.6712 - val_acc: 0.3947
# Epoch 68/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.9660 - acc: 0.2822 - val_loss: 1.6755 - val_acc: 0.3918
# Epoch 69/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.9558 - acc: 0.2909 - val_loss: 1.6449 - val_acc: 0.3713
# Epoch 70/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.9929 - acc: 0.2515 - val_loss: 1.6476 - val_acc: 0.3801
# Epoch 71/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.9467 - acc: 0.2617 - val_loss: 1.6771 - val_acc: 0.3743
# Epoch 72/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.9305 - acc: 0.3012 - val_loss: 1.6389 - val_acc: 0.4152
# Epoch 73/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.9691 - acc: 0.2807 - val_loss: 1.6165 - val_acc: 0.4444
# Epoch 74/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.9523 - acc: 0.2968 - val_loss: 1.6586 - val_acc: 0.4123
# Epoch 75/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.9484 - acc: 0.3304 - val_loss: 1.6304 - val_acc: 0.4035
# Epoch 76/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.9284 - acc: 0.3173 - val_loss: 1.5933 - val_acc: 0.3977
# Epoch 77/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.8837 - acc: 0.2982 - val_loss: 1.5752 - val_acc: 0.4064
# Epoch 78/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.8734 - acc: 0.3026 - val_loss: 1.5773 - val_acc: 0.3830
# Epoch 79/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.8720 - acc: 0.3202 - val_loss: 1.5775 - val_acc: 0.4181
# Epoch 80/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.8734 - acc: 0.3012 - val_loss: 1.5712 - val_acc: 0.4123
# Epoch 81/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.8839 - acc: 0.3012 - val_loss: 1.6036 - val_acc: 0.4094
# Epoch 82/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.8038 - acc: 0.3289 - val_loss: 1.5455 - val_acc: 0.4444
# Epoch 83/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.8815 - acc: 0.3304 - val_loss: 1.5427 - val_acc: 0.4357
# Epoch 84/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.9085 - acc: 0.3143 - val_loss: 1.5264 - val_acc: 0.4298
# Epoch 85/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.7796 - acc: 0.3450 - val_loss: 1.5259 - val_acc: 0.4532
# Epoch 86/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.8194 - acc: 0.3231 - val_loss: 1.5297 - val_acc: 0.4298
# Epoch 87/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.7869 - acc: 0.3348 - val_loss: 1.4978 - val_acc: 0.4444
# Epoch 88/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.8499 - acc: 0.3333 - val_loss: 1.4802 - val_acc: 0.4240
# Epoch 89/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.7945 - acc: 0.3494 - val_loss: 1.5031 - val_acc: 0.4181
# Epoch 90/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.8070 - acc: 0.3319 - val_loss: 1.4466 - val_acc: 0.4532
# Epoch 91/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.8270 - acc: 0.3333 - val_loss: 1.4481 - val_acc: 0.4503
# Epoch 92/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.7960 - acc: 0.3801 - val_loss: 1.4404 - val_acc: 0.5439
# Epoch 93/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.7282 - acc: 0.3465 - val_loss: 1.4149 - val_acc: 0.5088
# Epoch 94/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.7953 - acc: 0.3582 - val_loss: 1.4342 - val_acc: 0.4298
# Epoch 95/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.8153 - acc: 0.3392 - val_loss: 1.4573 - val_acc: 0.4094
# Epoch 96/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.7445 - acc: 0.3830 - val_loss: 1.4568 - val_acc: 0.4386
# Epoch 97/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.7303 - acc: 0.3699 - val_loss: 1.4131 - val_acc: 0.5088
# Epoch 98/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.6870 - acc: 0.3904 - val_loss: 1.3868 - val_acc: 0.4825
# Epoch 99/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.7034 - acc: 0.3640 - val_loss: 1.3678 - val_acc: 0.5088
# Epoch 100/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.6748 - acc: 0.4108 - val_loss: 1.3769 - val_acc: 0.4942
# Epoch 101/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.6828 - acc: 0.3904 - val_loss: 1.3739 - val_acc: 0.4795
# Epoch 102/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.7059 - acc: 0.3392 - val_loss: 1.3688 - val_acc: 0.4883
# Epoch 103/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.7122 - acc: 0.3611 - val_loss: 1.3723 - val_acc: 0.4883
# Epoch 104/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.6771 - acc: 0.3904 - val_loss: 1.3406 - val_acc: 0.5205
# Epoch 105/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.7328 - acc: 0.3772 - val_loss: 1.3705 - val_acc: 0.5175
# Epoch 106/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.6556 - acc: 0.3991 - val_loss: 1.3717 - val_acc: 0.5088
# Epoch 107/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.6379 - acc: 0.3728 - val_loss: 1.3280 - val_acc: 0.5058
# Epoch 108/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5866 - acc: 0.4006 - val_loss: 1.3752 - val_acc: 0.4854
# Epoch 109/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.7005 - acc: 0.3918 - val_loss: 1.3260 - val_acc: 0.4912
# Epoch 110/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.6303 - acc: 0.3830 - val_loss: 1.3091 - val_acc: 0.5351
# Epoch 111/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.6781 - acc: 0.3845 - val_loss: 1.3080 - val_acc: 0.5205
# Epoch 112/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.6369 - acc: 0.3713 - val_loss: 1.3337 - val_acc: 0.4942
# Epoch 113/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.6662 - acc: 0.3728 - val_loss: 1.3486 - val_acc: 0.5146
# Epoch 114/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.6026 - acc: 0.3889 - val_loss: 1.3043 - val_acc: 0.5643
# Epoch 115/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.6531 - acc: 0.3670 - val_loss: 1.3157 - val_acc: 0.5263
# Epoch 116/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.6557 - acc: 0.3845 - val_loss: 1.3339 - val_acc: 0.4854
# Epoch 117/1000
# 684/684 [==============================] - 3s 4ms/step - loss: 1.6479 - acc: 0.4123 - val_loss: 1.3127 - val_acc: 0.5322
# Epoch 118/1000
# 684/684 [==============================] - 3s 4ms/step - loss: 1.6410 - acc: 0.3787 - val_loss: 1.2975 - val_acc: 0.5731
# Epoch 119/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.6184 - acc: 0.4094 - val_loss: 1.2818 - val_acc: 0.5526
# Epoch 120/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.6324 - acc: 0.4079 - val_loss: 1.2853 - val_acc: 0.5614
# Epoch 121/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5769 - acc: 0.4167 - val_loss: 1.2598 - val_acc: 0.5702
# Epoch 122/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.6153 - acc: 0.4050 - val_loss: 1.2795 - val_acc: 0.5322
# Epoch 123/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.6046 - acc: 0.3728 - val_loss: 1.2577 - val_acc: 0.5234
# Epoch 124/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.6457 - acc: 0.4152 - val_loss: 1.2361 - val_acc: 0.5643
# Epoch 125/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5893 - acc: 0.4152 - val_loss: 1.2181 - val_acc: 0.5877
# Epoch 126/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5760 - acc: 0.4108 - val_loss: 1.2358 - val_acc: 0.5322
# Epoch 127/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5995 - acc: 0.4167 - val_loss: 1.2161 - val_acc: 0.5556
# Epoch 128/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5902 - acc: 0.4284 - val_loss: 1.1995 - val_acc: 0.5673
# Epoch 129/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5662 - acc: 0.4094 - val_loss: 1.2393 - val_acc: 0.5819
# Epoch 130/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4963 - acc: 0.4620 - val_loss: 1.2165 - val_acc: 0.5877
# Epoch 131/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5689 - acc: 0.4357 - val_loss: 1.2099 - val_acc: 0.5760
# Epoch 132/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5392 - acc: 0.4459 - val_loss: 1.2115 - val_acc: 0.5702
# Epoch 133/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5578 - acc: 0.4020 - val_loss: 1.1853 - val_acc: 0.5702
# Epoch 134/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5957 - acc: 0.4181 - val_loss: 1.1851 - val_acc: 0.5789
# Epoch 135/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5188 - acc: 0.4196 - val_loss: 1.1808 - val_acc: 0.5906
# Epoch 136/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5633 - acc: 0.4284 - val_loss: 1.1650 - val_acc: 0.6140
# Epoch 137/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4924 - acc: 0.4678 - val_loss: 1.1876 - val_acc: 0.5731
# Epoch 138/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5705 - acc: 0.4108 - val_loss: 1.1626 - val_acc: 0.6111
# Epoch 139/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5095 - acc: 0.4605 - val_loss: 1.2145 - val_acc: 0.5965
# Epoch 140/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5245 - acc: 0.4284 - val_loss: 1.1837 - val_acc: 0.5906
# Epoch 141/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5148 - acc: 0.4532 - val_loss: 1.1537 - val_acc: 0.6111
# Epoch 142/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5387 - acc: 0.4474 - val_loss: 1.1687 - val_acc: 0.5731
# Epoch 143/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5319 - acc: 0.4561 - val_loss: 1.1506 - val_acc: 0.6023
# Epoch 144/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5119 - acc: 0.4576 - val_loss: 1.1640 - val_acc: 0.5965
# Epoch 145/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4409 - acc: 0.4825 - val_loss: 1.1265 - val_acc: 0.5965
# Epoch 146/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5249 - acc: 0.4240 - val_loss: 1.1606 - val_acc: 0.5994
# Epoch 147/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5502 - acc: 0.4459 - val_loss: 1.1449 - val_acc: 0.6140
# Epoch 148/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4781 - acc: 0.4839 - val_loss: 1.1561 - val_acc: 0.6111
# Epoch 149/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4940 - acc: 0.4678 - val_loss: 1.1229 - val_acc: 0.6287
# Epoch 150/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4514 - acc: 0.4883 - val_loss: 1.1211 - val_acc: 0.6170
# Epoch 151/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4698 - acc: 0.4795 - val_loss: 1.1125 - val_acc: 0.6228
# Epoch 152/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5046 - acc: 0.4357 - val_loss: 1.1443 - val_acc: 0.5965
# Epoch 153/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4791 - acc: 0.4444 - val_loss: 1.1011 - val_acc: 0.6053
# Epoch 154/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4302 - acc: 0.4708 - val_loss: 1.1113 - val_acc: 0.5906
# Epoch 155/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5324 - acc: 0.4576 - val_loss: 1.1410 - val_acc: 0.5936
# Epoch 156/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4578 - acc: 0.4751 - val_loss: 1.1182 - val_acc: 0.6287
# Epoch 157/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4926 - acc: 0.4591 - val_loss: 1.1092 - val_acc: 0.6053
# Epoch 158/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3878 - acc: 0.4942 - val_loss: 1.0706 - val_acc: 0.6257
# Epoch 159/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5095 - acc: 0.4664 - val_loss: 1.0842 - val_acc: 0.6345
# Epoch 160/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5326 - acc: 0.4708 - val_loss: 1.1000 - val_acc: 0.6374
# Epoch 161/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5036 - acc: 0.4737 - val_loss: 1.0783 - val_acc: 0.6374
# Epoch 162/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4845 - acc: 0.4371 - val_loss: 1.0755 - val_acc: 0.6140
# Epoch 163/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.5092 - acc: 0.4561 - val_loss: 1.0995 - val_acc: 0.6140
# Epoch 164/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4289 - acc: 0.4810 - val_loss: 1.0760 - val_acc: 0.5994
# Epoch 165/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4415 - acc: 0.4825 - val_loss: 1.0798 - val_acc: 0.6140
# Epoch 166/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4194 - acc: 0.4927 - val_loss: 1.0722 - val_acc: 0.6579
# Epoch 167/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3681 - acc: 0.5132 - val_loss: 1.0597 - val_acc: 0.6199
# Epoch 168/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3964 - acc: 0.4693 - val_loss: 1.0400 - val_acc: 0.6257
# Epoch 169/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4050 - acc: 0.5146 - val_loss: 1.0511 - val_acc: 0.6345
# Epoch 170/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4330 - acc: 0.4737 - val_loss: 1.0395 - val_acc: 0.6404
# Epoch 171/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4460 - acc: 0.5029 - val_loss: 1.0402 - val_acc: 0.6550
# Epoch 172/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3447 - acc: 0.5015 - val_loss: 1.0169 - val_acc: 0.6550
# Epoch 173/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4254 - acc: 0.5073 - val_loss: 1.0345 - val_acc: 0.6462
# Epoch 174/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4283 - acc: 0.5073 - val_loss: 1.0523 - val_acc: 0.6257
# Epoch 175/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.3889 - acc: 0.4927 - val_loss: 1.0345 - val_acc: 0.6345
# Epoch 176/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4280 - acc: 0.4591 - val_loss: 1.0325 - val_acc: 0.6637
# Epoch 177/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4101 - acc: 0.5015 - val_loss: 1.0385 - val_acc: 0.6257
# Epoch 178/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4122 - acc: 0.4985 - val_loss: 1.0059 - val_acc: 0.6696
# Epoch 179/1000
# 684/684 [==============================] - 3s 4ms/step - loss: 1.3672 - acc: 0.5117 - val_loss: 1.0108 - val_acc: 0.6754
# Epoch 180/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4315 - acc: 0.4547 - val_loss: 1.0308 - val_acc: 0.6520
# Epoch 181/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.3519 - acc: 0.5044 - val_loss: 1.0085 - val_acc: 0.6637
# Epoch 182/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3573 - acc: 0.4956 - val_loss: 0.9944 - val_acc: 0.6579
# Epoch 183/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4091 - acc: 0.5044 - val_loss: 0.9715 - val_acc: 0.6667
# Epoch 184/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3268 - acc: 0.5088 - val_loss: 0.9962 - val_acc: 0.6608
# Epoch 185/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4204 - acc: 0.4795 - val_loss: 0.9872 - val_acc: 0.6784
# Epoch 186/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3895 - acc: 0.4985 - val_loss: 0.9837 - val_acc: 0.6784
# Epoch 187/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3915 - acc: 0.4825 - val_loss: 0.9936 - val_acc: 0.6345
# Epoch 188/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4224 - acc: 0.5015 - val_loss: 1.0110 - val_acc: 0.6608
# Epoch 189/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3716 - acc: 0.4868 - val_loss: 0.9916 - val_acc: 0.6462
# Epoch 190/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3472 - acc: 0.5132 - val_loss: 0.9801 - val_acc: 0.6725
# Epoch 191/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4219 - acc: 0.4722 - val_loss: 1.0053 - val_acc: 0.6813
# Epoch 192/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3146 - acc: 0.5336 - val_loss: 0.9607 - val_acc: 0.6462
# Epoch 193/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3555 - acc: 0.4883 - val_loss: 0.9741 - val_acc: 0.6462
# Epoch 194/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3621 - acc: 0.5117 - val_loss: 0.9931 - val_acc: 0.6637
# Epoch 195/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4070 - acc: 0.5102 - val_loss: 0.9885 - val_acc: 0.6608
# Epoch 196/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3051 - acc: 0.5219 - val_loss: 0.9715 - val_acc: 0.6608
# Epoch 197/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3626 - acc: 0.5146 - val_loss: 0.9695 - val_acc: 0.6316
# Epoch 198/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3683 - acc: 0.5175 - val_loss: 0.9516 - val_acc: 0.6871
# Epoch 199/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3460 - acc: 0.4971 - val_loss: 0.9415 - val_acc: 0.6842
# Epoch 200/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3094 - acc: 0.5409 - val_loss: 0.9479 - val_acc: 0.6637
# Epoch 201/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2844 - acc: 0.5322 - val_loss: 0.9514 - val_acc: 0.6871
# Epoch 202/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3540 - acc: 0.5175 - val_loss: 0.9442 - val_acc: 0.7018
# Epoch 203/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2119 - acc: 0.5526 - val_loss: 0.9353 - val_acc: 0.6667
# Epoch 204/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.4146 - acc: 0.5088 - val_loss: 0.9222 - val_acc: 0.6784
# Epoch 205/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3096 - acc: 0.5307 - val_loss: 0.9162 - val_acc: 0.6842
# Epoch 206/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3392 - acc: 0.4956 - val_loss: 0.9008 - val_acc: 0.6930
# Epoch 207/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3205 - acc: 0.5132 - val_loss: 0.9400 - val_acc: 0.6725
# Epoch 208/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3259 - acc: 0.5365 - val_loss: 0.9253 - val_acc: 0.6871
# Epoch 209/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2184 - acc: 0.5468 - val_loss: 0.9161 - val_acc: 0.6520
# Epoch 210/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3040 - acc: 0.5322 - val_loss: 0.9007 - val_acc: 0.7018
# Epoch 211/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2399 - acc: 0.5424 - val_loss: 0.9030 - val_acc: 0.6988
# Epoch 212/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3901 - acc: 0.5307 - val_loss: 0.9091 - val_acc: 0.6871
# Epoch 213/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3200 - acc: 0.5380 - val_loss: 0.8915 - val_acc: 0.6725
# Epoch 214/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3727 - acc: 0.5117 - val_loss: 0.9231 - val_acc: 0.7076
# Epoch 215/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3364 - acc: 0.5146 - val_loss: 0.9052 - val_acc: 0.6988
# Epoch 216/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2629 - acc: 0.5439 - val_loss: 0.8926 - val_acc: 0.7076
# Epoch 217/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2914 - acc: 0.5336 - val_loss: 0.8975 - val_acc: 0.7018
# Epoch 218/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3441 - acc: 0.5395 - val_loss: 0.8912 - val_acc: 0.6813
# Epoch 219/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2540 - acc: 0.5380 - val_loss: 0.8700 - val_acc: 0.7105
# Epoch 220/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2266 - acc: 0.5468 - val_loss: 0.8677 - val_acc: 0.7135
# Epoch 221/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2258 - acc: 0.5702 - val_loss: 0.8940 - val_acc: 0.6959
# Epoch 222/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2964 - acc: 0.5380 - val_loss: 0.8896 - val_acc: 0.7135
# Epoch 223/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3274 - acc: 0.5512 - val_loss: 0.8711 - val_acc: 0.7135
# Epoch 224/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2421 - acc: 0.5482 - val_loss: 0.8545 - val_acc: 0.7164
# Epoch 225/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.2536 - acc: 0.5336 - val_loss: 0.8593 - val_acc: 0.7164
# Epoch 226/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.3058 - acc: 0.5395 - val_loss: 0.8502 - val_acc: 0.7193
# Epoch 227/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2250 - acc: 0.5570 - val_loss: 0.8639 - val_acc: 0.7222
# Epoch 228/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2581 - acc: 0.5526 - val_loss: 0.8459 - val_acc: 0.7222
# Epoch 229/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2672 - acc: 0.5512 - val_loss: 0.8663 - val_acc: 0.7427
# Epoch 230/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2412 - acc: 0.5512 - val_loss: 0.8647 - val_acc: 0.6871
# Epoch 231/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2644 - acc: 0.5132 - val_loss: 0.8475 - val_acc: 0.7339
# Epoch 232/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2743 - acc: 0.5365 - val_loss: 0.8618 - val_acc: 0.7339
# Epoch 233/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2722 - acc: 0.5453 - val_loss: 0.8670 - val_acc: 0.7135
# Epoch 234/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2689 - acc: 0.5541 - val_loss: 0.8365 - val_acc: 0.7310
# Epoch 235/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2166 - acc: 0.5833 - val_loss: 0.8330 - val_acc: 0.7222
# Epoch 236/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2052 - acc: 0.5658 - val_loss: 0.8353 - val_acc: 0.7047
# Epoch 237/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2349 - acc: 0.5643 - val_loss: 0.8432 - val_acc: 0.7193
# Epoch 238/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2313 - acc: 0.5439 - val_loss: 0.8213 - val_acc: 0.7193
# Epoch 239/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2383 - acc: 0.5614 - val_loss: 0.8011 - val_acc: 0.7368
# Epoch 240/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1734 - acc: 0.5716 - val_loss: 0.8126 - val_acc: 0.7105
# Epoch 241/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2915 - acc: 0.5322 - val_loss: 0.8120 - val_acc: 0.7368
# Epoch 242/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2438 - acc: 0.5570 - val_loss: 0.8211 - val_acc: 0.7398
# Epoch 243/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1951 - acc: 0.5892 - val_loss: 0.8211 - val_acc: 0.7193
# Epoch 244/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2459 - acc: 0.5570 - val_loss: 0.8183 - val_acc: 0.7281
# Epoch 245/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1717 - acc: 0.5643 - val_loss: 0.7979 - val_acc: 0.7368
# Epoch 246/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2385 - acc: 0.5482 - val_loss: 0.8039 - val_acc: 0.7339
# Epoch 247/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2290 - acc: 0.5673 - val_loss: 0.8205 - val_acc: 0.7310
# Epoch 248/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1817 - acc: 0.5643 - val_loss: 0.8275 - val_acc: 0.7281
# Epoch 249/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2325 - acc: 0.5629 - val_loss: 0.8114 - val_acc: 0.7251
# Epoch 250/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2374 - acc: 0.5468 - val_loss: 0.8143 - val_acc: 0.7135
# Epoch 251/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1845 - acc: 0.5775 - val_loss: 0.7907 - val_acc: 0.7398
# Epoch 252/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2252 - acc: 0.5833 - val_loss: 0.7929 - val_acc: 0.7310
# Epoch 253/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1724 - acc: 0.5716 - val_loss: 0.8004 - val_acc: 0.7485
# Epoch 254/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1854 - acc: 0.5760 - val_loss: 0.7931 - val_acc: 0.7398
# Epoch 255/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2047 - acc: 0.5775 - val_loss: 0.8025 - val_acc: 0.7427
# Epoch 256/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.2317 - acc: 0.5658 - val_loss: 0.8196 - val_acc: 0.7398
# Epoch 257/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1890 - acc: 0.5556 - val_loss: 0.8092 - val_acc: 0.7281
# Epoch 258/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2264 - acc: 0.5731 - val_loss: 0.8115 - val_acc: 0.7368
# Epoch 259/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2033 - acc: 0.5731 - val_loss: 0.7933 - val_acc: 0.7339
# Epoch 260/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1705 - acc: 0.5833 - val_loss: 0.7996 - val_acc: 0.7456
# Epoch 261/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2368 - acc: 0.5819 - val_loss: 0.7973 - val_acc: 0.7427
# Epoch 262/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1466 - acc: 0.5746 - val_loss: 0.7862 - val_acc: 0.7398
# Epoch 263/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2001 - acc: 0.5819 - val_loss: 0.7804 - val_acc: 0.7515
# Epoch 264/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2431 - acc: 0.5409 - val_loss: 0.8198 - val_acc: 0.7427
# Epoch 265/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2215 - acc: 0.5760 - val_loss: 0.8068 - val_acc: 0.7427
# Epoch 266/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1974 - acc: 0.5789 - val_loss: 0.7985 - val_acc: 0.7368
# Epoch 267/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1523 - acc: 0.5863 - val_loss: 0.7853 - val_acc: 0.7456
# Epoch 268/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1594 - acc: 0.5980 - val_loss: 0.8146 - val_acc: 0.7456
# Epoch 269/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1705 - acc: 0.5585 - val_loss: 0.7983 - val_acc: 0.7456
# Epoch 270/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2052 - acc: 0.5629 - val_loss: 0.7938 - val_acc: 0.7632
# Epoch 271/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1868 - acc: 0.5746 - val_loss: 0.7838 - val_acc: 0.7602
# Epoch 272/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2070 - acc: 0.5819 - val_loss: 0.7909 - val_acc: 0.7661
# Epoch 273/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1348 - acc: 0.6199 - val_loss: 0.7765 - val_acc: 0.7602
# Epoch 274/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1111 - acc: 0.6009 - val_loss: 0.7788 - val_acc: 0.7719
# Epoch 275/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1876 - acc: 0.5687 - val_loss: 0.7913 - val_acc: 0.7398
# Epoch 276/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1898 - acc: 0.5804 - val_loss: 0.7807 - val_acc: 0.7602
# Epoch 277/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1582 - acc: 0.6009 - val_loss: 0.7738 - val_acc: 0.7456
# Epoch 278/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2427 - acc: 0.5599 - val_loss: 0.7801 - val_acc: 0.7485
# Epoch 279/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2581 - acc: 0.5512 - val_loss: 0.8004 - val_acc: 0.7368
# Epoch 280/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2357 - acc: 0.5643 - val_loss: 0.8007 - val_acc: 0.7281
# Epoch 281/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1387 - acc: 0.5760 - val_loss: 0.7715 - val_acc: 0.7632
# Epoch 282/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.1635 - acc: 0.5775 - val_loss: 0.7730 - val_acc: 0.7368
# Epoch 283/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1870 - acc: 0.5921 - val_loss: 0.7793 - val_acc: 0.7339
# Epoch 284/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1784 - acc: 0.5804 - val_loss: 0.7744 - val_acc: 0.7310
# Epoch 285/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1472 - acc: 0.5863 - val_loss: 0.7613 - val_acc: 0.7544
# Epoch 286/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1234 - acc: 0.6023 - val_loss: 0.7557 - val_acc: 0.7310
# Epoch 287/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2050 - acc: 0.6111 - val_loss: 0.7617 - val_acc: 0.7456
# Epoch 288/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1907 - acc: 0.5731 - val_loss: 0.7686 - val_acc: 0.7456
# Epoch 289/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2006 - acc: 0.5731 - val_loss: 0.7951 - val_acc: 0.7164
# Epoch 290/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.0471 - acc: 0.6213 - val_loss: 0.7680 - val_acc: 0.7485
# Epoch 291/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1634 - acc: 0.5877 - val_loss: 0.7601 - val_acc: 0.7632
# Epoch 292/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1101 - acc: 0.6067 - val_loss: 0.7599 - val_acc: 0.7368
# Epoch 293/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1886 - acc: 0.5614 - val_loss: 0.7607 - val_acc: 0.7661
# Epoch 294/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.1550 - acc: 0.5936 - val_loss: 0.7640 - val_acc: 0.7456
# Epoch 295/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.1497 - acc: 0.5789 - val_loss: 0.7816 - val_acc: 0.7310
# Epoch 296/1000
# 684/684 [==============================] - 3s 4ms/step - loss: 1.1407 - acc: 0.5936 - val_loss: 0.7465 - val_acc: 0.7427
# Epoch 297/1000
# 684/684 [==============================] - 3s 4ms/step - loss: 1.1813 - acc: 0.6009 - val_loss: 0.7425 - val_acc: 0.7573
# Epoch 298/1000
# 684/684 [==============================] - 3s 4ms/step - loss: 1.1467 - acc: 0.6009 - val_loss: 0.7553 - val_acc: 0.7632
# Epoch 299/1000
# 684/684 [==============================] - 3s 4ms/step - loss: 1.1562 - acc: 0.5863 - val_loss: 0.7462 - val_acc: 0.7544
# Epoch 300/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.1755 - acc: 0.5526 - val_loss: 0.7581 - val_acc: 0.7544
# Epoch 301/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1082 - acc: 0.6067 - val_loss: 0.7554 - val_acc: 0.7485
# Epoch 302/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.2111 - acc: 0.5936 - val_loss: 0.7576 - val_acc: 0.7398
# Epoch 303/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.1128 - acc: 0.6184 - val_loss: 0.7474 - val_acc: 0.7456
# Epoch 304/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1720 - acc: 0.6023 - val_loss: 0.7395 - val_acc: 0.7515
# Epoch 305/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1658 - acc: 0.5863 - val_loss: 0.7393 - val_acc: 0.7456
# Epoch 306/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1596 - acc: 0.5877 - val_loss: 0.7281 - val_acc: 0.7661
# Epoch 307/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1982 - acc: 0.5629 - val_loss: 0.7547 - val_acc: 0.7719
# Epoch 308/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1531 - acc: 0.5702 - val_loss: 0.7380 - val_acc: 0.7632
# Epoch 309/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.0881 - acc: 0.5848 - val_loss: 0.7346 - val_acc: 0.7515
# Epoch 310/1000
# 684/684 [==============================] - 3s 4ms/step - loss: 1.0715 - acc: 0.6111 - val_loss: 0.7226 - val_acc: 0.7544
# Epoch 311/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.1191 - acc: 0.6126 - val_loss: 0.7260 - val_acc: 0.7632
# Epoch 312/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1115 - acc: 0.5848 - val_loss: 0.7043 - val_acc: 0.7661
# Epoch 313/1000
# 684/684 [==============================] - 3s 4ms/step - loss: 1.1248 - acc: 0.5775 - val_loss: 0.7175 - val_acc: 0.7632
# Epoch 314/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1315 - acc: 0.6316 - val_loss: 0.7413 - val_acc: 0.7427
# Epoch 315/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1337 - acc: 0.6038 - val_loss: 0.7205 - val_acc: 0.7544
# Epoch 316/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.1604 - acc: 0.5936 - val_loss: 0.7097 - val_acc: 0.7719
# Epoch 317/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1060 - acc: 0.5965 - val_loss: 0.7028 - val_acc: 0.7602
# Epoch 318/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1335 - acc: 0.6126 - val_loss: 0.6977 - val_acc: 0.7719
# Epoch 319/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1334 - acc: 0.5848 - val_loss: 0.7073 - val_acc: 0.7632
# Epoch 320/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1691 - acc: 0.5906 - val_loss: 0.7196 - val_acc: 0.7632
# Epoch 321/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.0878 - acc: 0.6184 - val_loss: 0.7147 - val_acc: 0.7778
# Epoch 322/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1087 - acc: 0.6243 - val_loss: 0.6865 - val_acc: 0.7719
# Epoch 323/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.1923 - acc: 0.5833 - val_loss: 0.7057 - val_acc: 0.7719
# Epoch 324/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1058 - acc: 0.6184 - val_loss: 0.6954 - val_acc: 0.7719
# Epoch 325/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.1240 - acc: 0.5892 - val_loss: 0.7054 - val_acc: 0.7807
# Epoch 326/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.1010 - acc: 0.6243 - val_loss: 0.6913 - val_acc: 0.7807
# Epoch 327/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.0477 - acc: 0.6287 - val_loss: 0.7019 - val_acc: 0.7515
# Epoch 328/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.0881 - acc: 0.5936 - val_loss: 0.6835 - val_acc: 0.7749
# Epoch 329/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.0607 - acc: 0.6418 - val_loss: 0.6802 - val_acc: 0.7632
# Epoch 330/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1051 - acc: 0.6287 - val_loss: 0.6701 - val_acc: 0.7836
# Epoch 331/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.0478 - acc: 0.6096 - val_loss: 0.6847 - val_acc: 0.7749
# Epoch 332/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.0483 - acc: 0.6389 - val_loss: 0.6683 - val_acc: 0.7661
# Epoch 333/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1443 - acc: 0.5936 - val_loss: 0.7043 - val_acc: 0.7661
# Epoch 334/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.0630 - acc: 0.6053 - val_loss: 0.6749 - val_acc: 0.7690
# Epoch 335/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.1159 - acc: 0.6140 - val_loss: 0.6988 - val_acc: 0.7690
# Epoch 336/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.0860 - acc: 0.6140 - val_loss: 0.6696 - val_acc: 0.7661
# Epoch 337/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.0543 - acc: 0.6170 - val_loss: 0.6785 - val_acc: 0.7632
# Epoch 338/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.0676 - acc: 0.6082 - val_loss: 0.6816 - val_acc: 0.7661
# Epoch 339/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.0733 - acc: 0.6243 - val_loss: 0.6774 - val_acc: 0.7778
# Epoch 340/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.0716 - acc: 0.6155 - val_loss: 0.6661 - val_acc: 0.7924
# Epoch 341/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.0427 - acc: 0.6330 - val_loss: 0.6636 - val_acc: 0.7719
# Epoch 342/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1497 - acc: 0.5906 - val_loss: 0.6638 - val_acc: 0.7573
# Epoch 343/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.1201 - acc: 0.6038 - val_loss: 0.6817 - val_acc: 0.7515
# Epoch 344/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.0740 - acc: 0.6111 - val_loss: 0.6849 - val_acc: 0.7515
# Epoch 345/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.1064 - acc: 0.6360 - val_loss: 0.6745 - val_acc: 0.7836
# Epoch 346/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.0099 - acc: 0.6228 - val_loss: 0.6498 - val_acc: 0.7865
# Epoch 347/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.0707 - acc: 0.6257 - val_loss: 0.6776 - val_acc: 0.7749
# Epoch 348/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.0546 - acc: 0.6053 - val_loss: 0.6629 - val_acc: 0.7836
# Epoch 349/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.0762 - acc: 0.6096 - val_loss: 0.6775 - val_acc: 0.7895
# Epoch 350/1000
# 684/684 [==============================] - 2s 4ms/step - loss: 1.0902 - acc: 0.6126 - val_loss: 0.6697 - val_acc: 0.7865
# Epoch 351/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.0569 - acc: 0.6228 - val_loss: 0.6914 - val_acc: 0.7602
# Epoch 352/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 1.0851 - acc: 0.6067 - val_loss: 0.6953 - val_acc: 0.7573
# Epoch 353/1000
# 684/684 [==============================] - ETA: 0s - loss: 0.9852 - acc: 0.657 - 2s 3ms/step - loss: 0.9845 - acc: 0.6564 - val_loss: 0.6640 - val_acc: 0.7749
# Epoch 354/1000
# ...
# Epoch 884/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7564 - acc: 0.7368 - val_loss: 0.4311 - val_acc: 0.8567
# Epoch 885/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.6670 - acc: 0.7471 - val_loss: 0.4178 - val_acc: 0.8567
# Epoch 886/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7202 - acc: 0.7398 - val_loss: 0.4123 - val_acc: 0.8509
# Epoch 887/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7437 - acc: 0.7442 - val_loss: 0.4062 - val_acc: 0.8567
# Epoch 888/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7136 - acc: 0.7661 - val_loss: 0.4215 - val_acc: 0.8538
# Epoch 889/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7420 - acc: 0.7339 - val_loss: 0.4180 - val_acc: 0.8509
# Epoch 890/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.6842 - acc: 0.7602 - val_loss: 0.4187 - val_acc: 0.8509
# Epoch 891/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7811 - acc: 0.7310 - val_loss: 0.4134 - val_acc: 0.8480
# Epoch 892/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7645 - acc: 0.7339 - val_loss: 0.4140 - val_acc: 0.8567
# Epoch 893/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7110 - acc: 0.7500 - val_loss: 0.4161 - val_acc: 0.8480
# Epoch 894/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7522 - acc: 0.7427 - val_loss: 0.4289 - val_acc: 0.8480
# Epoch 895/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.6879 - acc: 0.7675 - val_loss: 0.4279 - val_acc: 0.8450
# Epoch 896/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7910 - acc: 0.7339 - val_loss: 0.4169 - val_acc: 0.8509
# Epoch 897/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7442 - acc: 0.7281 - val_loss: 0.4157 - val_acc: 0.8509
# Epoch 898/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.8005 - acc: 0.7295 - val_loss: 0.4185 - val_acc: 0.8538
# Epoch 899/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7584 - acc: 0.7310 - val_loss: 0.4123 - val_acc: 0.8596
# Epoch 900/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7790 - acc: 0.7412 - val_loss: 0.4184 - val_acc: 0.8538
# Epoch 901/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.8018 - acc: 0.7251 - val_loss: 0.4345 - val_acc: 0.8450
# Epoch 902/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7308 - acc: 0.7588 - val_loss: 0.4363 - val_acc: 0.8450
# Epoch 903/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7786 - acc: 0.7295 - val_loss: 0.4179 - val_acc: 0.8596
# Epoch 904/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7333 - acc: 0.7471 - val_loss: 0.4238 - val_acc: 0.8509
# Epoch 905/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7200 - acc: 0.7602 - val_loss: 0.4152 - val_acc: 0.8538
# Epoch 906/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7335 - acc: 0.7515 - val_loss: 0.4163 - val_acc: 0.8480
# Epoch 907/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.8393 - acc: 0.7208 - val_loss: 0.4123 - val_acc: 0.8480
# Epoch 908/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7239 - acc: 0.7529 - val_loss: 0.4108 - val_acc: 0.8480
# Epoch 909/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7686 - acc: 0.7529 - val_loss: 0.4153 - val_acc: 0.8450
# Epoch 910/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7173 - acc: 0.7617 - val_loss: 0.4150 - val_acc: 0.8421
# Epoch 911/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7519 - acc: 0.7661 - val_loss: 0.4084 - val_acc: 0.8480
# Epoch 912/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7778 - acc: 0.7164 - val_loss: 0.3989 - val_acc: 0.8538
# Epoch 913/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7988 - acc: 0.7237 - val_loss: 0.4060 - val_acc: 0.8596
# Epoch 914/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7317 - acc: 0.7529 - val_loss: 0.4024 - val_acc: 0.8509
# Epoch 915/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.8007 - acc: 0.7193 - val_loss: 0.4056 - val_acc: 0.8538
# Epoch 916/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7629 - acc: 0.7295 - val_loss: 0.4086 - val_acc: 0.8538
# Epoch 917/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7178 - acc: 0.7719 - val_loss: 0.4174 - val_acc: 0.8480
# Epoch 918/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7002 - acc: 0.7690 - val_loss: 0.4147 - val_acc: 0.8567
# Epoch 919/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7644 - acc: 0.7456 - val_loss: 0.4134 - val_acc: 0.8538
# Epoch 920/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7795 - acc: 0.7383 - val_loss: 0.4168 - val_acc: 0.8450
# Epoch 921/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7443 - acc: 0.7602 - val_loss: 0.4117 - val_acc: 0.8480
# Epoch 922/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.8134 - acc: 0.7354 - val_loss: 0.4036 - val_acc: 0.8567
# Epoch 923/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7852 - acc: 0.7398 - val_loss: 0.4075 - val_acc: 0.8509
# Epoch 924/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7661 - acc: 0.7251 - val_loss: 0.4051 - val_acc: 0.8596
# Epoch 925/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7482 - acc: 0.7500 - val_loss: 0.4071 - val_acc: 0.8596
# Epoch 926/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7803 - acc: 0.7368 - val_loss: 0.4099 - val_acc: 0.8626
# Epoch 927/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7521 - acc: 0.7456 - val_loss: 0.4106 - val_acc: 0.8626
# Epoch 928/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7667 - acc: 0.7368 - val_loss: 0.4104 - val_acc: 0.8655
# Epoch 929/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7592 - acc: 0.7456 - val_loss: 0.4094 - val_acc: 0.8626
# Epoch 930/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7652 - acc: 0.7354 - val_loss: 0.4074 - val_acc: 0.8626
# Epoch 931/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7191 - acc: 0.7412 - val_loss: 0.4171 - val_acc: 0.8567
# Epoch 932/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.8019 - acc: 0.7251 - val_loss: 0.4245 - val_acc: 0.8596
# Epoch 933/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7807 - acc: 0.7325 - val_loss: 0.4187 - val_acc: 0.8626
# Epoch 934/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7007 - acc: 0.7544 - val_loss: 0.4220 - val_acc: 0.8538
# Epoch 935/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7241 - acc: 0.7675 - val_loss: 0.4239 - val_acc: 0.8538
# Epoch 936/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7762 - acc: 0.7135 - val_loss: 0.4209 - val_acc: 0.8538
# Epoch 937/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7244 - acc: 0.7544 - val_loss: 0.4162 - val_acc: 0.8567
# Epoch 938/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7481 - acc: 0.7500 - val_loss: 0.4208 - val_acc: 0.8538
# Epoch 939/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7160 - acc: 0.7456 - val_loss: 0.4252 - val_acc: 0.8480
# Epoch 940/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.6839 - acc: 0.7558 - val_loss: 0.4208 - val_acc: 0.8480
# Epoch 941/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7208 - acc: 0.7456 - val_loss: 0.4219 - val_acc: 0.8421
# Epoch 942/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7466 - acc: 0.7383 - val_loss: 0.4168 - val_acc: 0.8509
# Epoch 943/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7830 - acc: 0.7529 - val_loss: 0.4139 - val_acc: 0.8567
# Epoch 944/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7855 - acc: 0.7325 - val_loss: 0.4159 - val_acc: 0.8567
# Epoch 945/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7832 - acc: 0.7398 - val_loss: 0.4134 - val_acc: 0.8596
# Epoch 946/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7326 - acc: 0.7383 - val_loss: 0.4154 - val_acc: 0.8567
# Epoch 947/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7198 - acc: 0.7617 - val_loss: 0.4173 - val_acc: 0.8567
# Epoch 948/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7007 - acc: 0.7558 - val_loss: 0.4168 - val_acc: 0.8567
# Epoch 949/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.6774 - acc: 0.7500 - val_loss: 0.4156 - val_acc: 0.8596
# Epoch 950/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.8235 - acc: 0.7310 - val_loss: 0.4154 - val_acc: 0.8596
# Epoch 951/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7343 - acc: 0.7412 - val_loss: 0.4188 - val_acc: 0.8596
# Epoch 952/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7929 - acc: 0.7412 - val_loss: 0.4274 - val_acc: 0.8509
# Epoch 953/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7592 - acc: 0.7485 - val_loss: 0.4322 - val_acc: 0.8480
# Epoch 954/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7443 - acc: 0.7368 - val_loss: 0.4327 - val_acc: 0.8480
# Epoch 955/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7508 - acc: 0.7471 - val_loss: 0.4227 - val_acc: 0.8538
# Epoch 956/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.6942 - acc: 0.7646 - val_loss: 0.4147 - val_acc: 0.8596
# Epoch 957/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7164 - acc: 0.7529 - val_loss: 0.4132 - val_acc: 0.8567
# Epoch 958/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.6792 - acc: 0.7500 - val_loss: 0.4139 - val_acc: 0.8509
# Epoch 959/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7155 - acc: 0.7368 - val_loss: 0.4119 - val_acc: 0.8567
# Epoch 960/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7895 - acc: 0.7354 - val_loss: 0.4174 - val_acc: 0.8509
# Epoch 961/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.6936 - acc: 0.7617 - val_loss: 0.4206 - val_acc: 0.8509
# Epoch 962/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7259 - acc: 0.7573 - val_loss: 0.4223 - val_acc: 0.8480
# Epoch 963/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7483 - acc: 0.7354 - val_loss: 0.4175 - val_acc: 0.8538
# Epoch 964/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.6426 - acc: 0.7646 - val_loss: 0.4126 - val_acc: 0.8509
# Epoch 965/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7908 - acc: 0.7558 - val_loss: 0.4184 - val_acc: 0.8567TA: 1s - loss: 0.
# Epoch 966/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7561 - acc: 0.7325 - val_loss: 0.4162 - val_acc: 0.8567
# Epoch 967/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.8229 - acc: 0.7310 - val_loss: 0.4239 - val_acc: 0.8480
# Epoch 968/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7118 - acc: 0.7442 - val_loss: 0.4203 - val_acc: 0.8509
# Epoch 969/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7474 - acc: 0.7442 - val_loss: 0.4199 - val_acc: 0.8567
# Epoch 970/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.8066 - acc: 0.7251 - val_loss: 0.4211 - val_acc: 0.8567
# Epoch 971/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7271 - acc: 0.7573 - val_loss: 0.4295 - val_acc: 0.8538
# Epoch 972/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7094 - acc: 0.7617 - val_loss: 0.4208 - val_acc: 0.8567
# Epoch 973/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7126 - acc: 0.7442 - val_loss: 0.4188 - val_acc: 0.8509
# Epoch 974/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7671 - acc: 0.7325 - val_loss: 0.4133 - val_acc: 0.8567
# Epoch 975/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7558 - acc: 0.7266 - val_loss: 0.4172 - val_acc: 0.8567
# Epoch 976/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.8368 - acc: 0.7237 - val_loss: 0.4179 - val_acc: 0.8480
# Epoch 977/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7471 - acc: 0.7281 - val_loss: 0.4243 - val_acc: 0.8450
# Epoch 978/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7320 - acc: 0.7602 - val_loss: 0.4275 - val_acc: 0.8421
# Epoch 979/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7285 - acc: 0.7251 - val_loss: 0.4206 - val_acc: 0.8450
# Epoch 980/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.8113 - acc: 0.7076 - val_loss: 0.4243 - val_acc: 0.8450
# Epoch 981/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7806 - acc: 0.7281 - val_loss: 0.4210 - val_acc: 0.8480
# Epoch 982/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7250 - acc: 0.7368 - val_loss: 0.4097 - val_acc: 0.8538
# Epoch 983/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.6968 - acc: 0.7456 - val_loss: 0.4058 - val_acc: 0.8626
# Epoch 984/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7137 - acc: 0.7456 - val_loss: 0.4008 - val_acc: 0.8655
# Epoch 985/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7733 - acc: 0.7456 - val_loss: 0.4174 - val_acc: 0.8538
# Epoch 986/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7216 - acc: 0.7471 - val_loss: 0.4164 - val_acc: 0.8538
# Epoch 987/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.6546 - acc: 0.7734 - val_loss: 0.4047 - val_acc: 0.8567
# Epoch 988/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7897 - acc: 0.7529 - val_loss: 0.4119 - val_acc: 0.8567
# Epoch 989/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.6930 - acc: 0.7602 - val_loss: 0.4179 - val_acc: 0.8509
# Epoch 990/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7764 - acc: 0.7368 - val_loss: 0.4232 - val_acc: 0.8509
# Epoch 991/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.6879 - acc: 0.7646 - val_loss: 0.4240 - val_acc: 0.8480
# Epoch 992/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7298 - acc: 0.7383 - val_loss: 0.4179 - val_acc: 0.8538
# Epoch 993/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.8199 - acc: 0.7105 - val_loss: 0.4158 - val_acc: 0.8567
# Epoch 994/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.6980 - acc: 0.7573 - val_loss: 0.4129 - val_acc: 0.8567
# Epoch 995/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7485 - acc: 0.7412 - val_loss: 0.4169 - val_acc: 0.8538
# Epoch 996/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7524 - acc: 0.7295 - val_loss: 0.4142 - val_acc: 0.8509
# Epoch 997/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7095 - acc: 0.7602 - val_loss: 0.4143 - val_acc: 0.8509
# Epoch 998/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.8067 - acc: 0.7368 - val_loss: 0.4130 - val_acc: 0.8509
# Epoch 999/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.7802 - acc: 0.7602 - val_loss: 0.4233 - val_acc: 0.8509
# Epoch 1000/1000
# 684/684 [==============================] - 2s 3ms/step - loss: 0.6697 - acc: 0.7646 - val_loss: 0.4106 - val_acc: 0.8567

# %%
model.save("./history/model08042018.h5")
with open('./history/history08042018.pkl', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)

# %%
model = load_model("./history/model08042018.h5")
with open('./history/history08042018.pkl', 'rb') as handle:
    load_history = pickle.load(handle)

# %%
score, acc = model.evaluate(x_test, Y_test)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 342/342 [==============================] - 0s 192us/step
# Test score: 0.410617060306
# Test accuracy: 0.856725145153

# %%
import matplotlib.pyplot as plt
# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Prediction section

# %%
x_predict = np.zeros([0, timesteps, dimensions])
y_actual = np.zeros([0])

test_data_per_word = 10

for word_no, word in enumerate(words):
    for data_no in range(test_data_per_word):
        try:
            with open("./record/{}/json_{}.txt".format(word, data_no)) as json_data:
                json_data = json.load(json_data)
        except Exception as s:
            print ('error log:', s)

        _timesteps = get_timesteps(json_data, pick_frame_every_no)
        _timesteps = np.vstack((_timesteps, np.zeros([timesteps - _timesteps.shape[0], dimensions])))
        x_predict = np.vstack((x_predict, [_timesteps]))
        y_actual = np.append(y_actual, word_no)
        
x_predict_norm = (x_predict-x_mean)/x_std
    
prediction = model.predict(x_predict_norm, verbose = 1)
# Out:
# 190/190 [==============================] - 0s 880us/step

# %%
y_actual = y_test
test_data_per_word = 18
prediction = model.predict(x_test, verbose = 1)
# Out:
# 342/342 [==============================] - 0s 1ms/step

# %%
confusion_matrix = np.zeros([len(words), len(words)])
prediction_word_index = np.argmax(prediction, axis = 1)

for idx in range(len(prediction_word_index)):
    actual = y_actual[idx]
    result = prediction_word_index[idx]
    confusion_matrix[int(actual)][result] += 1

# %%
test_acc = 0

for idx in range(len(words)):
    test_acc += confusion_matrix[idx][idx]
test_acc /= (test_data_per_word * len(words))

print(test_acc)
# Out:
# 0.856725146199

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
   
df_cm = pd.DataFrame(confusion_matrix, words, words)
plt.figure(figsize = (15,12))
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, cmap="Blues", annot=True, annot_kws={"size": 16})# font size
